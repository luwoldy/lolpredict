# %%
import pandas as pd
import requests
import json
import numpy as np
api_key = "RGAPI-562d0771-48bf-4db6-b87a-14b26f6d6ddc"

# %%
# To get matches we need to get the summoner ID for a player, using the userinput

userinput = "MoreFiero"

def get_accid(summoner):
    url = f"https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/{summoner}?api_key={api_key}"
    search = requests.get(url).json()
    summonid = search["accountId"]
    return summonid

acct_id = get_accid(userinput)
acct_id
# Out:
# 'LtRE5ilPODUVotcd3hYvlCuGmG6oBuQfvNGG1ASmbzdVdw'

# %%
#Get matches based on the summoner id from get_accid function
match_ids = []
match_url = f"https://na1.api.riotgames.com/lol/match/v4/matchlists/by-account/{acct_id}?queue=420&api_key={api_key}"
results = requests.get(match_url).json()

for result in results["matches"]:
    match_ids.append(result["gameId"])
    
match_results = []    
for game in match_ids:
    match_id = f"https://na1.api.riotgames.com/lol/match/v4/matches/{game}?api_key={api_key}"
    match_result = requests.get(match_id).json()
    match_results.append(match_result)

# match_result
match_ids
# Out:
# [2522970076,
#  2522924356,
#  2522884058,
#  2522829630,
#  2522824680,
#  2522802298,
#  2522750977,
#  2522698136,
#  2522714539,
#  2522539130,
#  2522545098,
#  2522479508,
#  2399425655]

# %%
# run through last ten games 
match_results[0]['participants']
# Out:
# [{'participantId': 1,
#   'teamId': 100,
#   'championId': 16,
#   'spell1Id': 3,
#   'spell2Id': 4,
#   'masteries': [{'masteryId': 6114, 'rank': 5},
#    {'masteryId': 6123, 'rank': 1},
#    {'masteryId': 6212, 'rank': 5},
#    {'masteryId': 6222, 'rank': 1},
#    {'masteryId': 6311, 'rank': 5},
#    {'masteryId': 6322, 'rank': 1},
#    {'masteryId': 6332, 'rank': 5},
#    {'masteryId': 6342, 'rank': 1},
#    {'masteryId': 6352, 'rank': 5},
#    {'masteryId': 6363, 'rank': 1}],
#   'runes': [{'runeId': 5257, 'rank': 9},
#    {'runeId': 5289, 'rank': 9},
#    {'runeId': 5315, 'rank': 5},
#    {'runeId': 5316, 'rank': 4},
#    {'runeId': 5357, 'rank': 3}],
#   'highestAchievedSeasonTier': 'SILVER',
#   'stats': {'participantId': 1,
#    'win': False,
#    'item0': 2302,
#    'item1': 3222,
#    'item2': 3117,
#    'item3': 3107,
#    'item4': 3504,
#    'item5': 0,
#    'item6': 3341,
#    'kills': 1,
#    'deaths': 6,
#    'assists': 21,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 1,
#    'killingSprees': 0,
#    'longestTimeSpentLiving': 972,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 34519,
#    'magicDamageDealt': 32116,
#    'physicalDamageDealt': 2372,
#    'trueDamageDealt': 30,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 9691,
#    'magicDamageDealtToChampions': 8571,
#    'physicalDamageDealtToChampions': 1089,
#    'trueDamageDealtToChampions': 30,
#    'totalHeal': 19704,
#    'totalUnitsHealed': 5,
#    'damageSelfMitigated': 13501,
#    'damageDealtToObjectives': 45,
#    'damageDealtToTurrets': 45,
#    'visionScore': 55,
#    'timeCCingOthers': 0,
#    'totalDamageTaken': 22792,
#    'magicalDamageTaken': 9416,
#    'physicalDamageTaken': 12979,
#    'trueDamageTaken': 396,
#    'goldEarned': 10086,
#    'goldSpent': 9600,
#    'turretKills': 0,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 30,
#    'neutralMinionsKilled': 0,
#    'neutralMinionsKilledTeamJungle': 0,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 481,
#    'champLevel': 14,
#    'visionWardsBoughtInGame': 3,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 28,
#    'wardsKilled': 3,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0},
#   'timeline': {'participantId': 1,
#    'creepsPerMinDeltas': {'10-20': 1.1,
#     '0-10': 0.2,
#     '20-30': 1.2999999999999998},
#    'xpPerMinDeltas': {'10-20': 367.6, '0-10': 257.1, '20-30': 391.9},
#    'goldPerMinDeltas': {'10-20': 268.4,
#     '0-10': 222.10000000000002,
#     '20-30': 347.7},
#    'csDiffPerMinDeltas': {'10-20': 1.0000000000000002,
#     '0-10': -0.050000000000000044,
#     '20-30': 1.85},
#    'xpDiffPerMinDeltas': {'10-20': 10,
#     '0-10': 29.700000000000017,
#     '20-30': -110.50000000000003},
#    'damageTakenPerMinDeltas': {'10-20': 585.1, '0-10': 312.1, '20-30': 833},
#    'damageTakenDiffPerMinDeltas': {'10-20': 24.150000000000006,
#     '0-10': 28.25,
#     '20-30': -230.70000000000005},
#    'role': 'DUO_SUPPORT',
#    'lane': 'BOTTOM'}},
#  {'participantId': 2,
#   'teamId': 100,
#   'championId': 77,
#   'spell1Id': 4,
#   'spell2Id': 11,
#   'masteries': [{'masteryId': 6111, 'rank': 5},
#    {'masteryId': 6122, 'rank': 1},
#    {'masteryId': 6131, 'rank': 5},
#    {'masteryId': 6142, 'rank': 1},
#    {'masteryId': 6151, 'rank': 5},
#    {'masteryId': 6161, 'rank': 1},
#    {'masteryId': 6312, 'rank': 5},
#    {'masteryId': 6321, 'rank': 1},
#    {'masteryId': 6331, 'rank': 5},
#    {'masteryId': 6343, 'rank': 1}],
#   'runes': [{'runeId': 5245, 'rank': 9},
#    {'runeId': 5289, 'rank': 9},
#    {'runeId': 5317, 'rank': 9},
#    {'runeId': 5337, 'rank': 3}],
#   'highestAchievedSeasonTier': 'SILVER',
#   'stats': {'participantId': 2,
#    'win': False,
#    'item0': 1416,
#    'item1': 3111,
#    'item2': 3144,
#    'item3': 3078,
#    'item4': 1043,
#    'item5': 0,
#    'item6': 3340,
#    'kills': 5,
#    'deaths': 9,
#    'assists': 6,
#    'largestKillingSpree': 3,
#    'largestMultiKill': 1,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 482,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 124975,
#    'magicDamageDealt': 2091,
#    'physicalDamageDealt': 113986,
#    'trueDamageDealt': 8897,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 8856,
#    'magicDamageDealtToChampions': 222,
#    'physicalDamageDealtToChampions': 7787,
#    'trueDamageDealtToChampions': 846,
#    'totalHeal': 9867,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 27821,
#    'damageDealtToObjectives': 9034,
#    'damageDealtToTurrets': 0,
#    'visionScore': 22,
#    'timeCCingOthers': 0,
#    'totalDamageTaken': 33640,
#    'magicalDamageTaken': 11670,
#    'physicalDamageTaken': 20787,
#    'trueDamageTaken': 1181,
#    'goldEarned': 10347,
#    'goldSpent': 10183,
#    'turretKills': 0,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 29,
#    'neutralMinionsKilled': 91,
#    'neutralMinionsKilledTeamJungle': 60,
#    'neutralMinionsKilledEnemyJungle': 31,
#    'totalTimeCrowdControlDealt': 584,
#    'champLevel': 14,
#    'visionWardsBoughtInGame': 1,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 11,
#    'wardsKilled': 0,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0},
#   'timeline': {'participantId': 2,
#    'creepsPerMinDeltas': {'10-20': 0.4, '0-10': 0, '20-30': 2.4},
#    'xpPerMinDeltas': {'10-20': 445.5,
#     '0-10': 306.6,
#     '20-30': 464.79999999999995},
#    'goldPerMinDeltas': {'10-20': 306.3,
#     '0-10': 283.6,
#     '20-30': 337.70000000000005},
#    'csDiffPerMinDeltas': {'10-20': -1.9000000000000001,
#     '0-10': -0.4,
#     '20-30': 0.7999999999999998},
#    'xpDiffPerMinDeltas': {'10-20': -24.400000000000063,
#     '0-10': 26.800000000000026,
#     '20-30': -105.1},
#    'damageTakenPerMinDeltas': {'10-20': 1104, '0-10': 604.5, '20-30': 1169.4},
#    'damageTakenDiffPerMinDeltas': {'10-20': 227.0999999999999,
#     '0-10': -47.19999999999999,
#     '20-30': -220.79999999999995},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}},
#  {'participantId': 3,
#   'teamId': 100,
#   'championId': 79,
#   'spell1Id': 12,
#   'spell2Id': 4,
#   'masteries': [{'masteryId': 6114, 'rank': 5},
#    {'masteryId': 6122, 'rank': 1},
#    {'masteryId': 6134, 'rank': 5},
#    {'masteryId': 6143, 'rank': 1},
#    {'masteryId': 6211, 'rank': 5},
#    {'masteryId': 6223, 'rank': 1},
#    {'masteryId': 6231, 'rank': 5},
#    {'masteryId': 6241, 'rank': 1},
#    {'masteryId': 6251, 'rank': 5},
#    {'masteryId': 6262, 'rank': 1}],
#   'runes': [{'runeId': 5273, 'rank': 9},
#    {'runeId': 5289, 'rank': 8},
#    {'runeId': 5297, 'rank': 1},
#    {'runeId': 5317, 'rank': 9},
#    {'runeId': 5357, 'rank': 3}],
#   'highestAchievedSeasonTier': 'SILVER',
#   'stats': {'participantId': 3,
#    'win': False,
#    'item0': 1054,
#    'item1': 3110,
#    'item2': 3065,
#    'item3': 3123,
#    'item4': 3047,
#    'item5': 3027,
#    'item6': 3340,
#    'kills': 4,
#    'deaths': 4,
#    'assists': 7,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 1,
#    'killingSprees': 1,
#    'longestTimeSpentLiving': 712,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 128657,
#    'magicDamageDealt': 102386,
#    'physicalDamageDealt': 26271,
#    'trueDamageDealt': 0,
#    'largestCriticalStrike': 597,
#    'totalDamageDealtToChampions': 16235,
#    'magicDamageDealtToChampions': 14612,
#    'physicalDamageDealtToChampions': 1623,
#    'trueDamageDealtToChampions': 0,
#    'totalHeal': 10021,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 33275,
#    'damageDealtToObjectives': 958,
#    'damageDealtToTurrets': 958,
#    'visionScore': 11,
#    'timeCCingOthers': 0,
#    'totalDamageTaken': 31465,
#    'magicalDamageTaken': 8839,
#    'physicalDamageTaken': 19025,
#    'trueDamageTaken': 3600,
#    'goldEarned': 11016,
#    'goldSpent': 11310,
#    'turretKills': 1,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 182,
#    'neutralMinionsKilled': 1,
#    'neutralMinionsKilledTeamJungle': 1,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 1785,
#    'champLevel': 16,
#    'visionWardsBoughtInGame': 1,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 10,
#    'wardsKilled': 0,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0},
#   'timeline': {'participantId': 3,
#    'creepsPerMinDeltas': {'10-20': 5.4, '0-10': 5.3, '20-30': 6.7},
#    'xpPerMinDeltas': {'10-20': 549.4000000000001,
#     '0-10': 383.8,
#     '20-30': 549.4},
#    'goldPerMinDeltas': {'10-20': 338.8, '0-10': 208.3, '20-30': 413.1},
#    'csDiffPerMinDeltas': {'10-20': -1.6,
#     '0-10': -1.2000000000000002,
#     '20-30': 0.9000000000000004},
#    'xpDiffPerMinDeltas': {'10-20': 169.60000000000002,
#     '0-10': -78.4,
#     '20-30': -25.200000000000045},
#    'damageTakenPerMinDeltas': {'10-20': 819.5999999999999,
#     '0-10': 493.79999999999995,
#     '20-30': 1089.3000000000002},
#    'damageTakenDiffPerMinDeltas': {'10-20': 68.49999999999994,
#     '0-10': 153.89999999999998,
#     '20-30': 701.6000000000001},
#    'role': 'SOLO',
#    'lane': 'TOP'}},
#  {'participantId': 4,
#   'teamId': 100,
#   'championId': 84,
#   'spell1Id': 14,
#   'spell2Id': 4,
#   'masteries': [{'masteryId': 6114, 'rank': 5},
#    {'masteryId': 6121, 'rank': 1},
#    {'masteryId': 6134, 'rank': 5},
#    {'masteryId': 6141, 'rank': 1},
#    {'masteryId': 6311, 'rank': 5},
#    {'masteryId': 6323, 'rank': 1},
#    {'masteryId': 6331, 'rank': 5},
#    {'masteryId': 6343, 'rank': 1},
#    {'masteryId': 6351, 'rank': 5},
#    {'masteryId': 6362, 'rank': 1}],
#   'highestAchievedSeasonTier': 'UNRANKED',
#   'stats': {'participantId': 4,
#    'win': False,
#    'item0': 3146,
#    'item1': 3124,
#    'item2': 3115,
#    'item3': 1028,
#    'item4': 1052,
#    'item5': 0,
#    'item6': 3340,
#    'kills': 13,
#    'deaths': 10,
#    'assists': 5,
#    'largestKillingSpree': 8,
#    'largestMultiKill': 2,
#    'killingSprees': 2,
#    'longestTimeSpentLiving': 497,
#    'doubleKills': 1,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 78073,
#    'magicDamageDealt': 24460,
#    'physicalDamageDealt': 52487,
#    'trueDamageDealt': 1126,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 21377,
#    'magicDamageDealtToChampions': 13367,
#    'physicalDamageDealtToChampions': 7097,
#    'trueDamageDealtToChampions': 912,
#    'totalHeal': 6001,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 9327,
#    'damageDealtToObjectives': 1140,
#    'damageDealtToTurrets': 1140,
#    'visionScore': 6,
#    'timeCCingOthers': 0,
#    'totalDamageTaken': 24743,
#    'magicalDamageTaken': 13549,
#    'physicalDamageTaken': 10189,
#    'trueDamageTaken': 1004,
#    'goldEarned': 11248,
#    'goldSpent': 10885,
#    'turretKills': 0,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 92,
#    'neutralMinionsKilled': 0,
#    'neutralMinionsKilledTeamJungle': 0,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 292,
#    'champLevel': 15,
#    'visionWardsBoughtInGame': 0,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 5,
#    'wardsKilled': 0,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0},
#   'timeline': {'participantId': 4,
#    'creepsPerMinDeltas': {'10-20': 2,
#     '0-10': 2.4000000000000004,
#     '20-30': 4.699999999999999},
#    'xpPerMinDeltas': {'10-20': 451.9, '0-10': 311.8, '20-30': 444.9},
#    'goldPerMinDeltas': {'10-20': 312.1, '0-10': 211.8, '20-30': 443.4},
#    'csDiffPerMinDeltas': {'10-20': -4.8999999999999995,
#     '0-10': -3.6999999999999997,
#     '20-30': -0.30000000000000027},
#    'xpDiffPerMinDeltas': {'10-20': 1.099999999999966,
#     '0-10': -108.89999999999998,
#     '20-30': -104.19999999999999},
#    'damageTakenPerMinDeltas': {'10-20': 544, '0-10': 403.8, '20-30': 1084.6},
#    'damageTakenDiffPerMinDeltas': {'10-20': 141.6,
#     '0-10': 184.8,
#     '20-30': 607.3},
#    'role': 'SOLO',
#    'lane': 'MIDDLE'}},
#  {'participantId': 5,
#   'teamId': 100,
#   'championId': 202,
#   'spell1Id': 7,
#   'spell2Id': 4,
#   'masteries': [{'masteryId': 6111, 'rank': 5},
#    {'masteryId': 6122, 'rank': 1},
#    {'masteryId': 6131, 'rank': 5},
#    {'masteryId': 6142, 'rank': 1},
#    {'masteryId': 6151, 'rank': 5},
#    {'masteryId': 6164, 'rank': 1},
#    {'masteryId': 6312, 'rank': 5},
#    {'masteryId': 6322, 'rank': 1},
#    {'masteryId': 6331, 'rank': 5},
#    {'masteryId': 6343, 'rank': 1}],
#   'runes': [{'runeId': 5245, 'rank': 9},
#    {'runeId': 5290, 'rank': 9},
#    {'runeId': 5317, 'rank': 9},
#    {'runeId': 5337, 'rank': 3}],
#   'highestAchievedSeasonTier': 'SILVER',
#   'stats': {'participantId': 5,
#    'win': False,
#    'item0': 3031,
#    'item1': 3508,
#    'item2': 3094,
#    'item3': 3009,
#    'item4': 0,
#    'item5': 0,
#    'item6': 3363,
#    'kills': 6,
#    'deaths': 6,
#    'assists': 8,
#    'largestKillingSpree': 3,
#    'largestMultiKill': 2,
#    'killingSprees': 2,
#    'longestTimeSpentLiving': 695,
#    'doubleKills': 1,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 135278,
#    'magicDamageDealt': 3086,
#    'physicalDamageDealt': 132191,
#    'trueDamageDealt': 0,
#    'largestCriticalStrike': 908,
#    'totalDamageDealtToChampions': 21120,
#    'magicDamageDealtToChampions': 1979,
#    'physicalDamageDealtToChampions': 19141,
#    'trueDamageDealtToChampions': 0,
#    'totalHeal': 2945,
#    'totalUnitsHealed': 2,
#    'damageSelfMitigated': 10297,
#    'damageDealtToObjectives': 3312,
#    'damageDealtToTurrets': 564,
#    'visionScore': 7,
#    'timeCCingOthers': 0,
#    'totalDamageTaken': 19962,
#    'magicalDamageTaken': 5053,
#    'physicalDamageTaken': 14376,
#    'trueDamageTaken': 532,
#    'goldEarned': 11491,
#    'goldSpent': 11160,
#    'turretKills': 0,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 202,
#    'neutralMinionsKilled': 0,
#    'neutralMinionsKilledTeamJungle': 0,
#    'neutralMinionsKilledEnemyJungle': 0,
#    'totalTimeCrowdControlDealt': 66,
#    'champLevel': 14,
#    'visionWardsBoughtInGame': 0,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 5,
#    'wardsKilled': 1,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0},
#   'timeline': {'participantId': 5,
#    'creepsPerMinDeltas': {'10-20': 7.5, '0-10': 5.4, '20-30': 7.2},
#    'xpPerMinDeltas': {'10-20': 408.9, '0-10': 322.9, '20-30': 444.2},
#    'goldPerMinDeltas': {'10-20': 359, '0-10': 283.9, '20-30': 393.6},
#    'csDiffPerMinDeltas': {'10-20': 1.0000000000000002,
#     '0-10': -0.050000000000000044,
#     '20-30': 1.85},
#    'xpDiffPerMinDeltas': {'10-20': 10,
#     '0-10': 29.700000000000017,
#     '20-30': -110.50000000000003},
#    'damageTakenPerMinDeltas': {'10-20': 532.9,
#     '0-10': 496.70000000000005,
#     '20-30': 550.2},
#    'damageTakenDiffPerMinDeltas': {'10-20': 24.150000000000006,
#     '0-10': 28.25,
#     '20-30': -230.70000000000005},
#    'role': 'DUO_CARRY',
#    'lane': 'BOTTOM'}},
#  {'participantId': 6,
#   'teamId': 200,
#   'championId': 18,
#   'spell1Id': 4,
#   'spell2Id': 7,
#   'masteries': [{'masteryId': 6111, 'rank': 5},
#    {'masteryId': 6121, 'rank': 1},
#    {'masteryId': 6134, 'rank': 5},
#    {'masteryId': 6143, 'rank': 1},
#    {'masteryId': 6151, 'rank': 5},
#    {'masteryId': 6162, 'rank': 1},
#    {'masteryId': 6211, 'rank': 5},
#    {'masteryId': 6223, 'rank': 1},
#    {'masteryId': 6232, 'rank': 5},
#    {'masteryId': 6243, 'rank': 1}],
#   'runes': [{'runeId': 5245, 'rank': 9},
#    {'runeId': 5275, 'rank': 9},
#    {'runeId': 5315, 'rank': 9},
#    {'runeId': 5335, 'rank': 3}],
#   'highestAchievedSeasonTier': 'UNRANKED',
#   'stats': {'participantId': 6,
#    'win': True,
#    'item0': 1055,
#    'item1': 3153,
#    'item2': 3006,
#    'item3': 3087,
#    'item4': 3031,
#    'item5': 0,
#    'item6': 3363,
#    'kills': 11,
#    'deaths': 6,
#    'assists': 9,
#    'largestKillingSpree': 5,
#    'largestMultiKill': 2,
#    'killingSprees': 3,
#    'longestTimeSpentLiving': 847,
#    'doubleKills': 2,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 156502,
#    'magicDamageDealt': 39796,
#    'physicalDamageDealt': 114168,
#    'trueDamageDealt': 2537,
#    'largestCriticalStrike': 799,
#    'totalDamageDealtToChampions': 25429,
#    'magicDamageDealtToChampions': 4662,
#    'physicalDamageDealtToChampions': 20054,
#    'trueDamageDealtToChampions': 712,
#    'totalHeal': 2729,
#    'totalUnitsHealed': 4,
#    'damageSelfMitigated': 10509,
#    'damageDealtToObjectives': 11267,
#    'damageDealtToTurrets': 11267,
#    'visionScore': 19,
#    'timeCCingOthers': 0,
#    'totalDamageTaken': 23376,
#    'magicalDamageTaken': 7279,
#    'physicalDamageTaken': 15968,
#    'trueDamageTaken': 128,
#    'goldEarned': 14476,
#    'goldSpent': 11400,
#    'turretKills': 3,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 155,
#    'neutralMinionsKilled': 18,
#    'neutralMinionsKilledTeamJungle': 6,
#    'neutralMinionsKilledEnemyJungle': 12,
#    'totalTimeCrowdControlDealt': 340,
#    'champLevel': 16,
#    'visionWardsBoughtInGame': 0,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 10,
#    'wardsKilled': 1,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': True,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': True,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0},
#   'timeline': {'participantId': 6,
#    'creepsPerMinDeltas': {'10-20': 6, '0-10': 4.6, '20-30': 2.7},
#    'xpPerMinDeltas': {'10-20': 483.9, '0-10': 267.5, '20-30': 505.8},
#    'goldPerMinDeltas': {'10-20': 446.20000000000005,
#     '0-10': 247.3,
#     '20-30': 477.3},
#    'csDiffPerMinDeltas': {'10-20': -1.0000000000000002,
#     '0-10': 0.050000000000000044,
#     '20-30': -1.85},
#    'xpDiffPerMinDeltas': {'10-20': -10,
#     '0-10': -29.700000000000017,
#     '20-30': 110.50000000000003},
#    'damageTakenPerMinDeltas': {'10-20': 661.2, '0-10': 349.8, '20-30': 1148.4},
#    'damageTakenDiffPerMinDeltas': {'10-20': -24.150000000000006,
#     '0-10': -28.25,
#     '20-30': 230.70000000000005},
#    'role': 'DUO_CARRY',
#    'lane': 'BOTTOM'}},
#  {'participantId': 7,
#   'teamId': 200,
#   'championId': 67,
#   'spell1Id': 14,
#   'spell2Id': 4,
#   'masteries': [{'masteryId': 6111, 'rank': 5},
#    {'masteryId': 6122, 'rank': 1},
#    {'masteryId': 6131, 'rank': 5},
#    {'masteryId': 6142, 'rank': 1},
#    {'masteryId': 6151, 'rank': 5},
#    {'masteryId': 6161, 'rank': 1},
#    {'masteryId': 6312, 'rank': 5},
#    {'masteryId': 6323, 'rank': 1},
#    {'masteryId': 6331, 'rank': 5},
#    {'masteryId': 6343, 'rank': 1}],
#   'runes': [{'runeId': 5245, 'rank': 7},
#    {'runeId': 5251, 'rank': 2},
#    {'runeId': 5277, 'rank': 9},
#    {'runeId': 5317, 'rank': 9},
#    {'runeId': 5335, 'rank': 2},
#    {'runeId': 5337, 'rank': 1}],
#   'highestAchievedSeasonTier': 'SILVER',
#   'stats': {'participantId': 7,
#    'win': True,
#    'item0': 3087,
#    'item1': 3031,
#    'item2': 3153,
#    'item3': 3086,
#    'item4': 1042,
#    'item5': 3006,
#    'item6': 3340,
#    'kills': 8,
#    'deaths': 5,
#    'assists': 3,
#    'largestKillingSpree': 4,
#    'largestMultiKill': 2,
#    'killingSprees': 3,
#    'longestTimeSpentLiving': 594,
#    'doubleKills': 2,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 166523,
#    'magicDamageDealt': 21284,
#    'physicalDamageDealt': 131119,
#    'trueDamageDealt': 14120,
#    'largestCriticalStrike': 990,
#    'totalDamageDealtToChampions': 22066,
#    'magicDamageDealtToChampions': 1472,
#    'physicalDamageDealtToChampions': 16820,
#    'trueDamageDealtToChampions': 3774,
#    'totalHeal': 3244,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 7097,
#    'damageDealtToObjectives': 21737,
#    'damageDealtToTurrets': 10249,
#    'visionScore': 20,
#    'timeCCingOthers': 0,
#    'totalDamageTaken': 18035,
#    'magicalDamageTaken': 9493,
#    'physicalDamageTaken': 8302,
#    'trueDamageTaken': 240,
#    'goldEarned': 14200,
#    'goldSpent': 12600,
#    'turretKills': 3,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 210,
#    'neutralMinionsKilled': 6,
#    'neutralMinionsKilledTeamJungle': 1,
#    'neutralMinionsKilledEnemyJungle': 5,
#    'totalTimeCrowdControlDealt': 96,
#    'champLevel': 16,
#    'visionWardsBoughtInGame': 0,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 13,
#    'wardsKilled': 0,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0},
#   'timeline': {'participantId': 7,
#    'creepsPerMinDeltas': {'10-20': 7, '0-10': 6.5, '20-30': 5.8},
#    'xpPerMinDeltas': {'10-20': 379.8,
#     '0-10': 462.20000000000005,
#     '20-30': 574.6},
#    'goldPerMinDeltas': {'10-20': 371.2, '0-10': 267.1, '20-30': 518.1},
#    'csDiffPerMinDeltas': {'10-20': 1.6,
#     '0-10': 1.2000000000000002,
#     '20-30': -0.9000000000000004},
#    'xpDiffPerMinDeltas': {'10-20': -169.60000000000002,
#     '0-10': 78.4,
#     '20-30': 25.200000000000045},
#    'damageTakenPerMinDeltas': {'10-20': 751.1, '0-10': 339.9, '20-30': 387.7},
#    'damageTakenDiffPerMinDeltas': {'10-20': -68.49999999999994,
#     '0-10': -153.89999999999998,
#     '20-30': -701.6000000000001},
#    'role': 'SOLO',
#    'lane': 'TOP'}},
#  {'participantId': 8,
#   'teamId': 200,
#   'championId': 163,
#   'spell1Id': 4,
#   'spell2Id': 3,
#   'masteries': [{'masteryId': 6114, 'rank': 5},
#    {'masteryId': 6122, 'rank': 1},
#    {'masteryId': 6134, 'rank': 5},
#    {'masteryId': 6142, 'rank': 1},
#    {'masteryId': 6312, 'rank': 5},
#    {'masteryId': 6322, 'rank': 1},
#    {'masteryId': 6331, 'rank': 3},
#    {'masteryId': 6332, 'rank': 2},
#    {'masteryId': 6343, 'rank': 1},
#    {'masteryId': 6351, 'rank': 5},
#    {'masteryId': 6361, 'rank': 1}],
#   'runes': [{'runeId': 5273, 'rank': 9},
#    {'runeId': 5289, 'rank': 3},
#    {'runeId': 5296, 'rank': 6},
#    {'runeId': 5316, 'rank': 9},
#    {'runeId': 5357, 'rank': 3}],
#   'highestAchievedSeasonTier': 'GOLD',
#   'stats': {'participantId': 8,
#    'win': True,
#    'item0': 2055,
#    'item1': 3157,
#    'item2': 3020,
#    'item3': 3165,
#    'item4': 3151,
#    'item5': 1052,
#    'item6': 3340,
#    'kills': 3,
#    'deaths': 5,
#    'assists': 16,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 1,
#    'killingSprees': 0,
#    'longestTimeSpentLiving': 522,
#    'doubleKills': 0,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 134707,
#    'magicDamageDealt': 119074,
#    'physicalDamageDealt': 15323,
#    'trueDamageDealt': 310,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 23287,
#    'magicDamageDealtToChampions': 22170,
#    'physicalDamageDealtToChampions': 1116,
#    'trueDamageDealtToChampions': 0,
#    'totalHeal': 1218,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 6212,
#    'damageDealtToObjectives': 5675,
#    'damageDealtToTurrets': 3251,
#    'visionScore': 38,
#    'timeCCingOthers': 0,
#    'totalDamageTaken': 14045,
#    'magicalDamageTaken': 7390,
#    'physicalDamageTaken': 6233,
#    'trueDamageTaken': 422,
#    'goldEarned': 13459,
#    'goldSpent': 11660,
#    'turretKills': 2,
#    'inhibitorKills': 2,
#    'totalMinionsKilled': 196,
#    'neutralMinionsKilled': 2,
#    'neutralMinionsKilledTeamJungle': 1,
#    'neutralMinionsKilledEnemyJungle': 1,
#    'totalTimeCrowdControlDealt': 490,
#    'champLevel': 16,
#    'visionWardsBoughtInGame': 3,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 15,
#    'wardsKilled': 0,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': True,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0},
#   'timeline': {'participantId': 8,
#    'creepsPerMinDeltas': {'10-20': 6.9, '0-10': 6.1, '20-30': 5},
#    'xpPerMinDeltas': {'10-20': 450.8, '0-10': 420.7, '20-30': 549.1},
#    'goldPerMinDeltas': {'10-20': 381.70000000000005,
#     '0-10': 247.1,
#     '20-30': 496.5},
#    'csDiffPerMinDeltas': {'10-20': 4.8999999999999995,
#     '0-10': 3.6999999999999997,
#     '20-30': 0.30000000000000027},
#    'xpDiffPerMinDeltas': {'10-20': -1.099999999999966,
#     '0-10': 108.89999999999998,
#     '20-30': 104.19999999999999},
#    'damageTakenPerMinDeltas': {'10-20': 402.4, '0-10': 219, '20-30': 477.3},
#    'damageTakenDiffPerMinDeltas': {'10-20': -141.6,
#     '0-10': -184.8,
#     '20-30': -607.3},
#    'role': 'SOLO',
#    'lane': 'MIDDLE'}},
#  {'participantId': 9,
#   'teamId': 200,
#   'championId': 117,
#   'spell1Id': 4,
#   'spell2Id': 3,
#   'masteries': [{'masteryId': 6211, 'rank': 5},
#    {'masteryId': 6221, 'rank': 1},
#    {'masteryId': 6231, 'rank': 5},
#    {'masteryId': 6241, 'rank': 1},
#    {'masteryId': 6311, 'rank': 5},
#    {'masteryId': 6322, 'rank': 1},
#    {'masteryId': 6332, 'rank': 5},
#    {'masteryId': 6342, 'rank': 1},
#    {'masteryId': 6352, 'rank': 5},
#    {'masteryId': 6362, 'rank': 1}],
#   'runes': [{'runeId': 5245, 'rank': 9},
#    {'runeId': 5297, 'rank': 9},
#    {'runeId': 5315, 'rank': 9},
#    {'runeId': 5347, 'rank': 2},
#    {'runeId': 5357, 'rank': 1}],
#   'highestAchievedSeasonTier': 'GOLD',
#   'stats': {'participantId': 9,
#    'win': True,
#    'item0': 3092,
#    'item1': 3107,
#    'item2': 3190,
#    'item3': 3111,
#    'item4': 2045,
#    'item5': 2055,
#    'item6': 3364,
#    'kills': 4,
#    'deaths': 5,
#    'assists': 17,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 2,
#    'killingSprees': 2,
#    'longestTimeSpentLiving': 384,
#    'doubleKills': 1,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 41031,
#    'magicDamageDealt': 33278,
#    'physicalDamageDealt': 7055,
#    'trueDamageDealt': 698,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 12160,
#    'magicDamageDealtToChampions': 9653,
#    'physicalDamageDealtToChampions': 2200,
#    'trueDamageDealtToChampions': 306,
#    'totalHeal': 3921,
#    'totalUnitsHealed': 8,
#    'damageSelfMitigated': 10263,
#    'damageDealtToObjectives': 2185,
#    'damageDealtToTurrets': 1853,
#    'visionScore': 54,
#    'timeCCingOthers': 0,
#    'totalDamageTaken': 16997,
#    'magicalDamageTaken': 7699,
#    'physicalDamageTaken': 9133,
#    'trueDamageTaken': 164,
#    'goldEarned': 12593,
#    'goldSpent': 10200,
#    'turretKills': 1,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 43,
#    'neutralMinionsKilled': 1,
#    'neutralMinionsKilledTeamJungle': 0,
#    'neutralMinionsKilledEnemyJungle': 1,
#    'totalTimeCrowdControlDealt': 465,
#    'champLevel': 15,
#    'visionWardsBoughtInGame': 2,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 16,
#    'wardsKilled': 6,
#    'firstBloodKill': False,
#    'firstBloodAssist': False,
#    'firstTowerKill': True,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0},
#   'timeline': {'participantId': 9,
#    'creepsPerMinDeltas': {'10-20': 0.6000000000000001,
#     '0-10': 1.1,
#     '20-30': 2.1},
#    'xpPerMinDeltas': {'10-20': 272.6, '0-10': 253.1, '20-30': 551.3},
#    'goldPerMinDeltas': {'10-20': 324.9, '0-10': 242, '20-30': 439.5},
#    'csDiffPerMinDeltas': {'10-20': -1.0000000000000002,
#     '0-10': 0.050000000000000044,
#     '20-30': -1.85},
#    'xpDiffPerMinDeltas': {'10-20': -10,
#     '0-10': -29.700000000000017,
#     '20-30': 110.50000000000003},
#    'damageTakenPerMinDeltas': {'10-20': 408.5, '0-10': 402.5, '20-30': 696.2},
#    'damageTakenDiffPerMinDeltas': {'10-20': -24.150000000000006,
#     '0-10': -28.25,
#     '20-30': 230.70000000000005},
#    'role': 'DUO_SUPPORT',
#    'lane': 'BOTTOM'}},
#  {'participantId': 10,
#   'teamId': 200,
#   'championId': 19,
#   'spell1Id': 11,
#   'spell2Id': 14,
#   'masteries': [{'masteryId': 6111, 'rank': 5},
#    {'masteryId': 6122, 'rank': 1},
#    {'masteryId': 6131, 'rank': 5},
#    {'masteryId': 6143, 'rank': 1},
#    {'masteryId': 6151, 'rank': 5},
#    {'masteryId': 6162, 'rank': 1},
#    {'masteryId': 6312, 'rank': 5},
#    {'masteryId': 6321, 'rank': 1},
#    {'masteryId': 6331, 'rank': 5},
#    {'masteryId': 6341, 'rank': 1}],
#   'runes': [{'runeId': 5163, 'rank': 1},
#    {'runeId': 5164, 'rank': 2},
#    {'runeId': 5196, 'rank': 1},
#    {'runeId': 5197, 'rank': 3},
#    {'runeId': 5245, 'rank': 9},
#    {'runeId': 5277, 'rank': 6},
#    {'runeId': 5317, 'rank': 5},
#    {'runeId': 5335, 'rank': 3}],
#   'highestAchievedSeasonTier': 'SILVER',
#   'stats': {'participantId': 10,
#    'win': True,
#    'item0': 3153,
#    'item1': 3748,
#    'item2': 3117,
#    'item3': 1416,
#    'item4': 3071,
#    'item5': 0,
#    'item6': 3340,
#    'kills': 9,
#    'deaths': 8,
#    'assists': 11,
#    'largestKillingSpree': 3,
#    'largestMultiKill': 2,
#    'killingSprees': 3,
#    'longestTimeSpentLiving': 467,
#    'doubleKills': 1,
#    'tripleKills': 0,
#    'quadraKills': 0,
#    'pentaKills': 0,
#    'unrealKills': 0,
#    'totalDamageDealt': 153205,
#    'magicDamageDealt': 35541,
#    'physicalDamageDealt': 104300,
#    'trueDamageDealt': 13363,
#    'largestCriticalStrike': 0,
#    'totalDamageDealtToChampions': 25195,
#    'magicDamageDealtToChampions': 9594,
#    'physicalDamageDealtToChampions': 13678,
#    'trueDamageDealtToChampions': 1922,
#    'totalHeal': 14620,
#    'totalUnitsHealed': 1,
#    'damageSelfMitigated': 21979,
#    'damageDealtToObjectives': 15449,
#    'damageDealtToTurrets': 275,
#    'visionScore': 23,
#    'timeCCingOthers': 0,
#    'totalDamageTaken': 34750,
#    'magicalDamageTaken': 10504,
#    'physicalDamageTaken': 23411,
#    'trueDamageTaken': 834,
#    'goldEarned': 13628,
#    'goldSpent': 13525,
#    'turretKills': 0,
#    'inhibitorKills': 0,
#    'totalMinionsKilled': 53,
#    'neutralMinionsKilled': 74,
#    'neutralMinionsKilledTeamJungle': 39,
#    'neutralMinionsKilledEnemyJungle': 35,
#    'totalTimeCrowdControlDealt': 507,
#    'champLevel': 16,
#    'visionWardsBoughtInGame': 0,
#    'sightWardsBoughtInGame': 0,
#    'wardsPlaced': 14,
#    'wardsKilled': 1,
#    'firstBloodKill': True,
#    'firstBloodAssist': False,
#    'firstTowerKill': False,
#    'firstTowerAssist': False,
#    'firstInhibitorKill': False,
#    'firstInhibitorAssist': False,
#    'combatPlayerScore': 0,
#    'objectivePlayerScore': 0,
#    'totalPlayerScore': 0,
#    'totalScoreRank': 0,
#    'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0},
#   'timeline': {'participantId': 10,
#    'creepsPerMinDeltas': {'10-20': 2.3000000000000003,
#     '0-10': 0.4,
#     '20-30': 1.6},
#    'xpPerMinDeltas': {'10-20': 469.90000000000003,
#     '0-10': 279.8,
#     '20-30': 569.9},
#    'goldPerMinDeltas': {'10-20': 399.4,
#     '0-10': 299.70000000000005,
#     '20-30': 449.9},
#    'csDiffPerMinDeltas': {'10-20': 1.9000000000000001,
#     '0-10': 0.4,
#     '20-30': -0.7999999999999998},
#    'xpDiffPerMinDeltas': {'10-20': 24.400000000000063,
#     '0-10': -26.800000000000026,
#     '20-30': 105.1},
#    'damageTakenPerMinDeltas': {'10-20': 876.9000000000001,
#     '0-10': 651.7,
#     '20-30': 1390.1999999999998},
#    'damageTakenDiffPerMinDeltas': {'10-20': -227.0999999999999,
#     '0-10': 47.19999999999999,
#     '20-30': 220.79999999999995},
#    'role': 'NONE',
#    'lane': 'JUNGLE'}}]

# %%
kills = []
deaths = []
longestTimeSpentLiving = []
wardsPlaced = []
goldEarned = []
champLevel = []
firstTowerAssist = []
firstInhibitorAssist = []
assists = []
firstBloodAssist = []
visionScore = []

for match in match_results:
    participant_check = match_result['participantIdentities']
    participant_info = []


    for i in participant_check:
        participant_info.append(i)


    players = []

    for player in participant_info:
        players.append(player['player'])
    
    summoners = []
    for i in players:
        summoners.append(i['summonerName'])
    
    participantNo = summoners.index(userinput)+1
    participantNo

    participants = match_result['participants']
    participants
    
    statlist = []
    for k in participants:
        statlist.append(k['stats'])

    for i in statlist:
        if participantNo == i['participantId']:
            kills.append(i['kills'])
            deaths.append(i['deaths'])
            longestTimeSpentLiving.append(i['longestTimeSpentLiving'])
            wardsPlaced.append(i['wardsPlaced'])
            goldEarned.append(i['goldEarned'])
            champLevel.append(i['champLevel'])
            if i['firstTowerAssist']==True:
                firstTowerAssist.append(1)
            else: 
                firstTowerAssist.append(0)
            if i['firstInhibitorAssist']==True:
                firstInhibitorAssist.append(1)
            else: 
                firstInhibitorAssist.append(0)
            assists.append(i['assists'])
            if i['firstBloodAssist']==True:
                firstBloodAssist.append(1)
            else:
                firstBloodAssist.append(0)
            visionScore.append(i['visionScore'])

# %%
longestTimeSpentLiving
# Out:
# [492, 492, 492, 492, 492, 492, 492, 492, 492, 492, 492, 492, 492]

# %%
# LEUL'S PARTICIPANT ID CODE

# def find_participant_id(profile_name):
#    for match in match_results["participantIdentities"]:
#        if match["player"]["summonerName"] == profile_name:
#            return match["participantId"]
    
# find_participant_id("morefiero")
